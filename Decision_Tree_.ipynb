# %% [markdown]
# ##comments
# 1. add code
# 2. ID3 example on short dataset
# 3. code on dataset (explain parameters-in short)
#
# deadline= wednessday Jan 25,2023

# %% [markdown]
# ---
#
# #<center>$\color{red}{\text{What is a Dicision Tree}}$</center>
#
# ---

# %% [markdown]
# Decision tree, as the name suggest its a tree(reverse) like model of decisions. It is one of the supervised machine learning(ML) model algortithm.
#
# A decision tree can be visually represented. It is drawn upside down with its **root** at the top.  The conditions are called **internal node**. The tree splits into branches. Branches are called **edges**. The end of the branch that doesnt split anymore is the decision. The decisions are called **leaf**.

# %% [markdown]
# #<center> ![Blank diagram (2).jpeg](data:image/jpeg;base64,...)</center>

# %% [markdown]
# Decision Tree can be further classified as classification trees and regression trees. Classification tree is used to classify and regression trees are used to predict continuous values.
#
# Decision tree algorithms are referred to as CART (classification and regression trees) algorithm,ID3 algorithm, CHAID, ID 4.5 algorithm and so on. ID3 algoritm is the most used algorithm used for dicision tree.
#
#
# We calculate how much accuracy cost us for each split. The split that costs least is chosen. Moreover, the algorithm is recursive in nature and it's also known as greedy algorithm.
#
# We want lowering the cost as much as possible. This makes the root node as best predictor/classifier.

# %% [markdown]
# ---
#
# #<center>$\color{red}{\text{Cost of split}}$</center>
#
# ---

# %% [markdown]
# For cost calculation one methods tries to find most homogenous branchs or branches having groups with same response or impurity.
# For example:
#
# 1. If we have four red balls in a box and take a ball from the box. Then the impurity will be 0. Collection of homogenous elements or simillar element has impurity of 0.
# 2. If we have one red ball and three blue balls. Then a little more information is needed to identify a random ball's color. Thus, there will be small amount of impurity.
#
# 3. If we have two red balls and two blue balls. Then, maximum number of information is required to identify a random balls color. Thus, the impurity will be maximum of 1
#
#
# There are two methods mostly use to calculate cost calculation.
# 1. Entropy/impurity
# 2. Gini index/Gini impurity
#
#
#
# ###Entropy:
# Entropy is the amount of information needed to express a single element out of collection of elements. It ranges between 0 and 1.
#
# The formula for entropy,
# $$
# \text { Entropy }=-\sum_{i=1}^n p_i * \log \left(p_i\right)
# $$
#
# Here, p is the probabilty each individual element from a collection of elements of i=1,2,3,4.....n. The entropy is the negative of the sum of product of each probability and it's logrithmic value.
#
#
# ###Gini index / Gini impurity:
# Gini index is also a measure of inequality in a collection of elements. It has value between 0 and 1 . Gini index of value 0 means sample are perfectly homogeneous and all element are similar. Gini index of value 1 means maximam inequality among elements. It is sum of the square of the probabilities of each class.
# The formula used for Gini index:
# $$
# \text { Gini index }=1-\sum_{i=1}^n p_i^2
# $$
#
# Here, p is the probabilty each individual element from a collection of elements of i=1,2,3,4.....n.
#
#
# The Gini index calculated by summing the square of probabilites for each individual elements. Then, subtracting it from 1.

# %% [markdown]
# ---
#
# #<center>$\color{red}{\text{Implementation of decesion tree algorithm from mathmatical perspective}}$</center>
#
# ---

# %% [markdown]
# The most used algoritms used for decesion tree algoritm ar ID3 and CART.
#
# ###CART(Classification and regression tree) algoritm:
# * CART algoritm is used for generating both classification tree and regression tree and used for binary classification.
# * CART uses Gini index as metric/cost function to evaluate split in feature selection in case of classification tree.
# * CART uses least square as a metric to select features in case of Regression tree.
#
# For example:
#
# # <center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# outlook, temperature, humidity and wind is the features of data.
#
#
# For the the above features, we need to caclulate gini index. Outlook has features sunny, overcast and rainfall.
#
# For example. the columns of the table bellow calculates instances,decision, gini index for each below and weighted gini index for outlook.
#
# the rows represented for each values.
#
# first row for outlook==sunny we have 2 yes instances, 3 no instances, total instances 5.
#
# The gini index will be, Gini index(outlook=sunny)= 1-(2/5)²-(3/5)² = 1- 0.16–0.36 = 0.48
#
# simillarly, we have Gini index(outlook=overcast)=0 and Gini index(outlook=rainfall)=0.48
#
# Gini(outlook) = (5/14)*0.48 + (4/14) *0 + (5/14)*0.48 = 0.342

# %% [markdown]
# |<font size="4"> Outlook</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(outlook)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> sunny </font>| <font size="3"> 2 </font>| <font size="3"> 3 </font>| <font size="3"> 5 </font>| <font size="3">0.48 </font>| <font size="3">  </font>|
#   | <font size="3"> overcast </font>| <font size="3"> 4 </font>| <font size="3"> 0 </font>| <font size="3"> 4 </font>| <font size="3"> 0 </font>|<font size="3">  0.342 </font>|
#   | <font size="3"> rainfall </font>| <font size="3"> 3 </font>| <font size="3"> 2|<font size="3"> 5</font>|<font size="3"> 0.48</font>|<font size="3"> </font>

# %% [markdown]
# Next we calculated Gini(temperature), Gini(Humidity) and Gini(wind),

# %% [markdown]
# |<font size="4"> temperature</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(temperature)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> hot </font>| <font size="3"> 2 </font>| <font size="3"> 3 </font>| <font size="3"> 5 </font>| <font size="3">0.48 </font>| <font size="3">  </font>|
#   | <font size="3"> cold </font>| <font size="3"> 4 </font>| <font size="3"> 0 </font>| <font size="3"> 4 </font>| <font size="3"> 0 </font>|<font size="3">  0.342 </font>|
#   | <font size="3"> mild </font>| <font size="3"> 3 </font>| <font size="3"> 2|<font size="3"> 5</font>|<font size="3"> 0.48</font>|<font size="3"> </font>

# %% [markdown]
# |<font size="4">humidity</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(humidity)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> High </font>| <font size="3"> 3</font>| <font size="3"> 4 </font>| <font size="3"> 7 </font>| <font size="3">0.489 </font>| <font size="3">  </font>|
#   | <font size="3"> Normal </font>| <font size="3"> 6 </font>| <font size="3"> 1 </font>| <font size="3"> 7 </font>| <font size="3"> 0.244 </font>|<font size="3">  0.367 </font>|

# %% [markdown]
# |<font size="4">wind</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(wind)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> weak </font>| <font size="3"> 6</font>| <font size="3"> 2 </font>| <font size="3"> 8 </font>| <font size="3">0.375 </font>| <font size="3">  </font>|
#   | <font size="3"> strong </font>| <font size="3"> 3 </font>| <font size="3"> 3 </font>| <font size="3"> 6 </font>| <font size="3"> 0.5 </font>|<font size="3">  0.428 </font>|

# %% [markdown]
# Finally, the features and Gini index of all features.

# %% [markdown]
# |<font size="4">Features</font>| <font size="4"> Gini index </font>|
#  | :--: | :--: |
#  | <font size="3"> outlook </font>| <font size="3"> 0.342</font>|
# | <font size="3"> temperature </font>| <font size="3"> 0.439</font>|
#  | <font size="3"> humidity </font>| <font size="3"> 0.367</font>|
# | <font size="3"> wind </font>| <font size="3"> 0.428</font>|

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# |<font size="4"> temperature</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(temperature)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> hot </font>| <font size="3"> 0 </font>| <font size="3"> 2 </font>| <font size="3"> 2 </font>| <font size="3">0 </font>| <font size="3">  </font>|
#   | <font size="3"> cool </font>| <font size="3"> 1 </font>| <font size="3"> 0 </font>| <font size="3"> 1 </font>| <font size="3"> 0 </font>|<font size="3">  0.2 </font>|
#   | <font size="3"> mild </font>| <font size="3"> 1 </font>| <font size="3"> 1</front>|<font size="3"> 2</font>|<font size="3"> 0.5</font>|<font size="3"> </font>

# %% [markdown]
# |<font size="4"> humidity</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(humidity)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> high </font>| <font size="3"> 0 </font>| <font size="3"> 3 </font>| <font size="3"> 3 </font>| <font size="3">0 </font>| <font size="3">  </font>|
#   | <font size="3"> Normal </font>| <font size="3"> 2 </font>| <font size="3"> 0 </font>| <font size="3"> 2 </font>| <font size="3"> 0 </font>|<font size="3">  0 </font>|

# %% [markdown]
# |<font size="4"> wind</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(wind)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> weak </font>| <font size="3"> 1 </font>| <font size="3"> 2 </font>| <font size="3"> 3 </font>| <font size="3">0.44 </font>| <font size="3">  </font>|
#   | <font size="3"> strong </font>| <font size="3"> 1 </font>| <font size="3"> 1 </font>| <font size="3"> 2 </font>| <font size="3"> 0.5 </font>|<font size="3">  0.466 </font>|

# %% [markdown]
# |<font size="4">Features</font>| <font size="4"> Gini index </font>|
#  | :--: | :--: |
#  | <font size="3"> temperature </font>| <font size="3"> 0.2</font>|
# | <font size="3"> humidity </font>| <font size="3"> 0.0</font>|
# | <font size="3"> wind </font>| <font size="3"> 0.466</font>|

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# # <center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# As decision for above features is Gini index is 0. Thus,we can devide randomly.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# From the given two table, the decision is always ‘No’ when humidity is ‘high’ and decision is always ‘Yes’ when humidity is ‘normal’. So we got leaf node. now decision tree can be viewed as,

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# Gini index for temperature for rainfall outlook

# %% [markdown]
# |<font size="4"> temperature</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(temperature for rainfall outlook)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> cool </font>| <font size="3"> 1 </font>| <font size="3"> 1 </font>| <font size="3"> 2 </font>| <font size="3">.5 </font>| <font size="3">  </font>|
#   | <font size="3"> mild </font>| <font size="3"> 2 </font>| <font size="3"> 1 </font>| <font size="3"> 3 </font>| <font size="3"> 0.444 </font>|<font size="3">  0.466 </font>|

# %% [markdown]
# Gini index for humidity for rainfall outlook

# %% [markdown]
# |<font size="4"> humidity</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(humidity for rainfall outlook)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> high </font>| <font size="3"> 1 </font>| <font size="3"> 1 </font>| <font size="3"> 2 </font>| <font size="3">.5 </font>| <font size="3">  </font>|
#   | <font size="3"> normal </font>| <font size="3"> 2 </font>| <font size="3"> 1 </font>| <font size="3"> 3 </font>| <font size="3"> 0.444 </font>|<font size="3">  0.466 </font>|

# %% [markdown]
# |<font size="4">wind</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Gini index</font>|<font size="4">Gini(rainfall outlook feature)</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> weak </font>| <font size="3"> 3 </font>| <font size="3"> 0 </font>| <font size="3"> 3 </font>| <font size="3">0 </font>| <font size="3">  </font>|
#   | <font size="3"> strong </font>| <font size="3"> 0 </font>| <font size="3"> 2 </font>| <font size="3"> 2 </font>| <font size="3"> 0 </font>|<font size="3">  0 </font>|

# %% [markdown]
# Decision on rainfall outlook factor:

# %% [markdown]
# |<font size="4">Features</font>| <font size="4"> Gini index </font>|
#  | :--: | :--: |
#  | <font size="3"> temperature </font>| <font size="3"> 0.466</font>|
# | <font size="3"> humidity </font>| <font size="3"> 0.466</font>|
# | <font size="3"> wind </font>| <font size="3"> 0</font>|

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# From the above two table, the decision is always ‘No’ when wind is ‘strong’ and decision is always ‘Yes’ when wind is ‘weak’. So we got leaf node.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# ###ID3 algoritm:
# * ID3 algorithm is used for generating classification tree.
# * ID3 algorithm uses entropy function to evaluate split in feature selection in case of classification tree.
#
# For example:

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# Root node
# From the data set,we have
# 1. Number of observations $=14$
# 2. Number of observations having Decision 'Yes' $=9$
# 3. probability of 'Yes', $p$ (Yes) $=9 / 14$
# 4. Number of observations having Decision 'No' $=5$
# 5. probability of 'No', $\mathrm{p}(\mathrm{No})=5 / 14$
# Entropy(Decision $)=-\mathrm{p}(\text { Yes })^* \log _2 \mathrm{p}($ Yes $)-\mathrm{p}(\text { No })^* \log _2 \mathrm{p}($ No $)$
# Entropy $($Decision$)=-(9 / 14) * \log _2(9 / 14)-(5 / 14) * \log _2(5 / 14)=0.94$
#
#
#
# As we have four attribute, outlook, temperature, humidity, and wind

# %% [markdown]
# Information Gain on sunny outlook factor,

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# 1. Number of instance for sunny outlook factor $=5$
# 2. Decision ='Yes', prob(Decision='Yes' $\mid$ outlook $=$ sunny $)=2 / 5$
# 3. Decision ='No', $\operatorname{prob}($ Decision='No' $\mid$ outlook $=$ sunny $)=3 / 5$
# $$
# \begin{aligned}
# & \text { Entropy( Decision | outlook = sunny) }=-(2 / 5) * \log _2(2 / 5)-(3 / 5) * \log _2(3 / 5)=0.97 \\
# & \text { Entropy( Decision | outlook = overcast })=-(4 / 4) * \log _2(4 / 4)=0 \\
# & \text { Entropy( Decision | outlook =rainfall) }=-(3 / 5) * \log _2(3 / 5)-(2 / 5) * \log _2(2 / 5)= \\
# & \text { Gain(Decision, outlook) = Entropy(Decision })-\mathrm{p}(\text { Decision } \mid \text { outlook=sunny }) * \\
# & \log _2 \mathrm{p}\left(\text { Decision |outlook=sunny) } \text { - p(Decision |outlook=overcast) } * \log _2 \mathrm{P}(\text { Decision | }\right. \\
# & \text { outlook=overcast) - p(Decision |outlook=rainfall) } * \log _2 \mathrm{P}(\text { Decision } \mid \text { outlook=rainfall) } \\
# & \text { Gain(Decision, outlook) }=0.94-(5 / 14) * 0.97-(4 / 4) * 0-(5 / 14) * 0.97=0.247
# \end{aligned}
# $$

# %% [markdown]
# Summary of Information Gain for all the attribute
#
#     Gain(Decision, outlook) = 0.247
#     Gain(Decision, wind ) = 0.048
#     Gain(Decision, temperature) = 0.029
#     Gain(Decision, humidity) = 0.151

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# Entropy(Decision| outlook=sunny)=-(2/5)*log2(2/5)-(3/5)*log2(3/5)=0.97

# %% [markdown]
# |<font size="4"> temperature</font>| <font size="4"> Yes </font>|<font size="4"> No </font>| <font size="4"> Instances </font>|<font size="4"> Entropy</font>|<font size="4">Gain</font>
#  | :--: | :--: | :--: | :--: | :--: | :-: |
#  | <font size="3"> hot </font>| <font size="3"> 0 </font>| <font size="3"> 2 </font>| <font size="3"> 2 </font>| <font size="3">0 </font>| <font size="3">  </font>|
#   | <font size="3"> cool </font>| <font size="3"> 1 </font>| <font size="3"> 0 </font>| <font size="3"> 1 </font>| <font size="3"> 0 </font>|<font size="3">  0.57 </font>|
#   | <font size="3"> mild </font>| <font size="3"> 1 </font>| <font size="3"> 1</front>|<font size="3"> 2</font>|<font size="3"> 1</font>|<font size="3"> </font>

# %% [markdown]
# Summary of information gain on all attribute under Sunny outlook factor,
# 1. Gain(sunny,temp)=0.57
# 2. Gain(sunny,humidity)=0.97
# 3. Gain(sunny,wind)=0.019

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
#     Total number of Observation =4
#     Prob(Decision=’Yes’,overcast)=1
#     Prob(Decision=’No’,overcast)=0
#
# Since, All the decision are ‘Yes’ , so
#
# Entropy(Decision, Overcast)=0
#
# So, if outlook=overcast then decision is ‘Yes’ . so, It is a leaf node. It cant be further divided.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# Information Gain on humidity factor
#
# humidity takes two value, normal and high.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# From the both table, you can infer that, whenever humidity is high decision is ‘No’
#
# And, when humidity is normal decision is ‘Yes’
# Information Gain on Rainfall outlook factor

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...) </center>

# %% [markdown]
#     Number of instance for rainfall outlook factor=5
#     Decision =’Yes’, prob(Decision=’Yes’ | outlook=rainfall)=3/5
#     Decision =’No’, prob(Decision=’No’ | outlook=rainfall)=2/5
#
# Information Gain on Wind under rainfall outlook factor

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# Entropy (rainfall, wind) =0
#
# Gain(rainfall, wind)=0.97
# Summary of information Gain on all features under rainfall outlook factor
#
#     Gain(rainfall, wind)=0.97
#     Gain(rainfall, temp)=0.019
#
# So, wind attribute has highest information gain. So it is selected as next node under rainfall outlook factor.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# Information Gain on wind
#
# wind takes two value, weak and strong.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# From the two table, the decision is always ‘No’ when wind is ‘strong’ and decision is always ‘Yes’ when wind is ‘weak’. So wind is also an leaf node.

# %% [markdown]
# #<center>![image.png](data:image/png;base64,...)</center>

# %% [markdown]
# ---
#
# #<center>$\color{red}{\text{Simple coding implementation of decision tree}}$</center>
#
# ---

# %%
import numpy as np
import pandas as pd
import requests

# %%
class Node(object):
    def __init__(self,value,is_leaf=False):
        self.value = value
        self.left = None
        self.right = None
        self.gini_value = None
        self.col_index = None
        self.is_leaf = is_leaf

class decision_tree_classifier(object):
    def __init__(self,min_samples=10,min_gini=0.2,max_depth=5):
        self.root = None
        self.min_samples = min_samples
        self.min_gini = min_gini
        self.max_depth = max_depth
        self.classes = None
    def fit(self,data):
        self.classes = list(set(int(row[-1]) for row in data))
        self.root = self.create_node(data)
        self.build_tree(self.root,current_depth = 0)
        return self.root

    def create_node(self,data):
        node = Node(None)

        ### checking if node can be further split using minimum gini as criterion
        gini_score = self.gini_index(data)
        if gini_score <= self.min_gini:
            node.is_leaf = True
            node.value = np.bincount([row[-1] for row in data]).argmax()
            node.gini_value = gini_score
            return node

        ### checking if node has enough samples to be split again
        if len(data) <= self.min_samples:
            node.is_leaf = True
            node.value = np.bincount([row[-1] for row in data]).argmax()
            node.gini_value = gini_score
            return node


        ### finding minimum gini impurity split
        gini_index = 1.0
        for col_index in range(len(data[0])-1):
            for row_index in range(len(data)):
                value = data[row_index][col_index]
                child = self.get_split(data,col_index,value)
                node_gini_index = self.calculate_gini_index(value,child)
                if node_gini_index < gini_index:
                    gini_index = node_gini_index
                    node.value = value
                    node.gini_value = node_gini_index
                    node.col_index = col_index
                    node.left = child['l']
                    node.right = child['r']
        return node

    def gini_index(self,data):
        size = len(data)
        instances = [0] * len(self.classes)
        for row in data:
            instances[int(row[-1])] += 1
        return 1 - np.sum([(val/size)**2 for val in instances]) if size > 0 else 1

    def calculate_gini_index(self,value,child):
        group_size = [len(child['l']),len(child['r'])]
        left_gini = self.gini_index(child['l'])
        right_gini =  self.gini_index(child['r'])
        return (group_size[0]/np.sum(group_size) * left_gini) + (group_size[1]/np.sum(group_size) * right_gini)

    def get_split(self,data,col_index,value):
        left_child, right_child = [], []
        for index in range(len(data)):
            if data[index][col_index] < value:
                left_child.append(data[index])
            if data[index][col_index] > value:
                right_child.append(data[index])
        return {'l':left_child, 'r':right_child}

    def build_tree(self,node,current_depth):
        ## create left subtree for the node if possible under constraints
        if  current_depth < self.max_depth:
            ## creating left node
            if node.left is not None and isinstance(node.left,list):
                left_node = self.create_node(node.left)
                node.left = left_node
                if node.left.is_leaf is not True:
                    self.build_tree(node.left,current_depth+1)
            if node.right is not None and isinstance(node.right,list):
            ## creating right node
                right_node = self.create_node(node.right)
                node.right = right_node
                if node.right.is_leaf is not True:
                    self.build_tree(node.right,current_depth+1)

    def traverse(self):
        tree = {'root':str(self.root.value)}
        stack = [self.root]
        node = self.root
        while len(stack) > 0:
            while node is not None:
                stack.append(node)
                node = node.left
            node = stack.pop(-1)
            if node.is_leaf is not True:
                tree[str(node.value)] = {'left':node.left.value,'right':node.right.value,'feature':node.col_index,'gini value':node.gini_value}
            else:
                tree[str(node.value)] = {'left':'None','right':'None','class label':node.value,'gini value':node.gini_value,'leaf':True}
            node = node.right
        return tree

    def predict(self,sample):
        predictions = []
        for row in sample:
            node = self.root
            while node.is_leaf is not True:
                if row[node.col_index] < node.value:
                    node = node.left
                    continue
                if row[node.col_index] >= node.value:
                    node = node.right
            predictions.append(node.value)
        return predictions

def accuracy(data):
    dt = decision_tree_classifier()
    tree = dt.fit(data)
    print('<========= decision tree ===========>')
    print(dt.traverse())
    predictions = dt.predict(data[0:-1][0:-1])
    true_values = [row[-1] for row in data]
    return '{:1f}'.format(sum([t==p for t,p in zip(true_values, predictions)])/len(true_values) *100 ) + '% accuracy'


def flower_to_id(value):
    if value == 'Iris-virginica':
        return 2
    if value == 'Iris-versicolor':
        return 0
    if value == 'Iris-setosa':
        return 1


def get_data():
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
    values = requests.get(url).content.decode('utf-8').split('\n')
    data_set = [val.split(',') for val in values]
    data_df = pd.DataFrame(data=data_set,columns=['sepal_length','sepal_width','petal_length','petal_width','flower'])
    data_df = data_df.dropna()
    data_df[['sepal_length','sepal_width','petal_length','petal_width']] = data_df[['sepal_length','sepal_width','petal_length','petal_width']].astype('float')
    data_df['flower'] = data_df['flower'].map(flower_to_id)
    return data_df

data = get_data()
print(accuracy(data.to_numpy()))
# Out:
# <========= decision tree ===========>
# {'root': '1.0', '1': {'left': 'None', 'right': 'None', 'class label': 1, 'gini value': 0.0, 'leaf': True}, '1.0': {'left': 1, 'right': 1.7, 'feature': 3, 'gini value': 0.32333258139709753}, '0': {'left': 'None', 'right': 'None', 'class label': 0, 'gini value': 0.1619753086419753, 'leaf': True}, '1.7': {'left': 0, 'right': 2, 'feature': 3, 'gini value': 0.10159791898922337}, '2': {'left': 'None', 'right': 'None', 'class label': 2, 'gini value': 0.04253308128544431, 'leaf': True}}
# 94.666667% accuracy

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
iris = load_iris()
x, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, y)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# ---
#
# #<center>$\color{red}{\text{Random forest tree algoritm}}$</center>
#
# ---
